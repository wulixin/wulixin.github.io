# %% [markdown]
# 网络数据如何获取(爬取)

# %% [markdown]
# 抓取 1 urllib内建模块urllib.request  <br/>
#     2 Requests 第三方库 <br/>
#     3 Scrapy 框架 <br/>
# 解析
#     1 BeautifulSoup库 <br/>
#     2 re模块    <br/>

# %% [markdown]
# robots.txt文件

# %%
抓取网站情况多样，有时还会很复杂，这需要长期的积累，不能一蹴而就，列举几种情况：
a.假设获取的是二进制文件，则可以借鉴如下方法保存数据：

# %%
import requests

r = requests.get('https://www.baidu.com/img/bd_logo1.png')
with open('baidu.png', 'wb') as fp:
   fp.write(r.content)

# %% [markdown]
# b. 有些网站会对http请求的Headers的User-Agent进行检测，需将headers信息传递给get函数的headers参数，例如豆瓣最近也有了此要求，例如知乎，直接访问会返回400，加上headers参数后可正确返回：

# %%
re = requests.get('https://www.zhihu.com')
re.status_code

# headers可从http测试网站https://httpbin.org或浏览器的“开发者工具”获得
headers = {"User-Agent": "Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.83 Safari/535.11"}
re = requests.get('https://www.zhihu.com', headers = headers)
re.status_code
# Out:
# 200

# %% [markdown]
# 反爬的策略还有很多，需要逐渐熟悉，有些网站要想获得数据还需要登录，需要分析登录需要的属性。
# c. 被JS渲染过的页面内容获取
# 可以通过浏览器的“开发者工具”功能寻找真正提供数据的页面，有时会有一定的难度。

# %%
from bs4 import BeautifulSoup

# %%
markup='<p class="title"> <b>The Little Prince</b></p>'

# %%
soup=BeautifulSoup(markup,'lxml')

# %%
soup.b
# Out:
# <b>The Little Prince</b>

# %%
tag=soup.p

# %%
tag.name
# Out:
# 'p'

# %%
tag.attrs
# Out:
# {'class': ['title']}

# %%
tag['class']
# Out:
# ['title']

# %%
type(tag.string)
# Out:
# NoneType

# %%
soup.find_all('b')
# Out:
# [<b>The Little Prince</b>]

# %%
import requests 
from bs4 import BeautifulSoup

# %%
r=requests.get('https://book.douban.com/subject/1084336/coments/')

# %%
soup=BeautifulSoup(r.text,'lxml')
pattern=soup.find_all('span','short')

# %%
for item in pattern:
    print(item.string)

# %%
week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
week[0:5]
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
week[-7:-3]
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday']

# %%
week[:-2]
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
x, y = 3, 5.678
print(f"x={x}, y={y:.2f}")
# Out:
# x=3, y=5.68

# %%
print(F"x={x}, y={y:.2f}")
# Out:
# x=3, y=5.68

# %%
x=3
print(f"{x*4+5}")
# Out:
# 17

# %%
s = "Hello"
print(f"{s.lower()}")
# Out:
# hello

# %%
print(b'\xe6\x89\x8e\xe5\xbf\x83\xe4\xba\x86\xef\xbc\x8c\xe8\x80\x81\xe9\x93\x81')
# Out:
# b'\xe6\x89\x8e\xe5\xbf\x83\xe4\xba\x86\xef\xbc\x8c\xe8\x80\x81\xe9\x93\x81'
