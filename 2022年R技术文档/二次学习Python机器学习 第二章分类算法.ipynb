# %% [markdown]
# # 使用Python实现感知器学习算法

# %%
import numpy as np

# %% [markdown]
# 按照Python开发的惯例对于哪些并非在初始化对象时创建但又被对象中其它方法调用的属性，可以再后面添加一个下划线，例如self.w_

# %%
class Perceptron(object):
    '''Perceptron classifier 
    
    Parameters 
    ----------
    eta: float 
        Learning rate (between 0.0 and 1.0)
    n_iter :int 
        Passes over the training dataset.
        
    Attributes 
    ----------
    w_：1d-array 
        Weights after fitting 
    errors_:list 
        Number of misclassifications in every epoch.
         
    '''
    
    def __init__ (self,eta=0.01,n_iter=10) :
        
        self.eta=eta
        self.n_iter=n_iter
        
    def fit(self,X,y):
        
        ''' Fit training data.
        Parameters 
        ----------
        X:{array-like},shape={n_samples,n_features}
            Training vectors, where n_samples
            is the number of samples and n_features is the number of features.
    y: array-like,shape=[n_samples]
            Target values.
            
    Returns
    
    -------------
    
    self :object 
    
    '''
        
    self.w_ = np.zeros(1 + X.shape[1])
    self.errors_ = []
    
    
    for _  in range(self.n_iter):
        errors=0
        for xi, target in zip(X,y):  
            update=self.eta  * (target - self.predict(xi))
            self.w_[1:] += update * xi
            self.w_[0] += update
            errors += int(update != 0.0)
        self.errors_.append(errors)
        
    return self 


def net_input(self,X):
    '''Calculate net input '''
    return np.dot(X,self.w_[1:]) + self.w_[0]

def predict(self,X):
    '''Return class label after unit step''' 
    return np.where(self.net_input(X) >= 0.0,1,-1)
# Out:
#   File "/var/folders/xw/n8d_gn89383dctwyvrp_drr40000gn/T/ipykernel_911/895677569.py", line 57
#     return self
#     ^
# SyntaxError: 'return' outside function

# %% [markdown]
# .append .shape for _ in  np.dot np.where

# %% [markdown]
# 在感知器实现的过程中，实例化了一个perceptron对象时，给出了一个学习效率eta和在训练数据集上进行迭代的次数N_iter,通过fit方法，将self.w_中的权值初始化为一个零向量，其中m是数据集中维度的数量，再次基础上增加一个0权重列

# %% [markdown]
# numpy使用了高速优化的线性代数库，实现了基础线性代数子程序，basic linear algebra subprogram 和线性代数包 linear algebra packages

# %%
import pandas as pd

# %%
from sklearn import datasets

# %%
df=datasets.load_iris()

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
y=df.iloc[0:100,4].values
y=np.where(y=="iris-setosa",-1,1)

# %%
plt.scatter(x,x,color='red',marker='x',label='setosa')
plt.scatter(x,x,color='blue',marker='o',label='versicolor')
plt.xlabel('petal length')
plt.ylabel('sepal length')
plt.legend(loc='upper left')
plt.show()

# %%
import IPython

# %% [markdown]
# # 使用scikit-learn 学习分类算法 第三章

# %%
from sklearn import datasets 
import numpy as np 
iris =datasets.load_iris()
X=iris.data[:,[2,3]]
y=iris.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
X_train_std=sc.transform(X_train)
X_test_std=sc.transform(X_test)

# %%
from sklearn.linear_model import Perceptron 
ppn=Perceptron()
ppn.fit(X_train_std,y_train)
# Out:
# Perceptron()

# %%
y_pred=ppn.predict(X_test_std)

# %%
print('Misclassified samples: %d'% (y_test != y_pred).sum())
# Out:
# Misclassified samples: 5

# %% [markdown]
# 许多机器学习从业者通常使用准确率而不是误分类率来判断一个模型

# %% [raw]
# # sklearn metrics 实现了许多不同的性能矩阵

# %%
from sklearn.metrics import accuracy_score

# %%
print('Accuracy: %.2f' % accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.89

# %% [raw]
# #学习曲线等图形工具来检查是否过度拟合，

# %%
from matplotlib.colors import ListedColormap 
import matplotlib.pyplot as plt

# %%
def plot_decision_regions(X,y,classifier,
                         test_idx=None,resolution=0.02):
    #setup marker generator and color map 
    markers = ('s','k','o','^','v')
    colors= ('red','blue','lightgreen','gray','cyan')
     
    cmap=ListedColormap(colors[:len(np.unique(y))])
    
    # plot the decision surface 
    x1_min,x1_max=X[:,0].min()-1,X[:,0].max()+1
    x2_min,x2_max=X[:,1].min()-1,X[:,1].max()+1
    
    xx1,xx2=np.meshgrid(np.arange(x1_min,x1_max,resolution),
                       np.arange(x2_min,x2_max,resolution))
    
    z=classifier.predict(np.array([xx1.ravel(),xx2.ravel()]).T)
    
    z=z.reshape(xx1.shape)
    
    plt.contourf(xx1,xx2,z,alpha=0.4,cmap=cmap)
    plt.ylim(xx1.min(),xx1.max())
    plt.xlim(xx2.min(),xx2.max())
    
    # plot all samples
    X_test,y_test=X[test_idx,:],y[test_idx]
    for idx,cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y==cl,0],y=X[y==cl,1],alpha=0.8,c=cmap(idx),
                    marker=markers[idx],label=cl)
        
        # highlight the test samples 
        
        if test_idx:
            X_test,y_test=X[test_idx,:],y[test_idx]
            plt.scatter(X_test[:,0],X_test[:,1],c='',
                        alpha=1.0, linewidth=1,marker='o',s=55,label='test set')

# %%
X_combined_std=np.vstack((X_train_std,X_test_std))
y_combined=np.hstack((y_train,y_test))

# %%
plot_decision_regions(X=X_combined_std,y=y_combined,classifier=ppn,
                      test_idx=range(105,150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     366     if isinstance(c, str):
# ...

# %% [markdown]
# logistics regression 逻辑谛回归 是一个分类模型 而不是回归模型

# %% [markdown]
# logit(p)=log(p/(1-p))

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
def sigmoid(z):
    return 1.0/(1.0+np.exp(-z))

# %%
z=np.arange(-7,7,0.1)
phi_z=sigmoid(z)

# %%
plt.plot(z,phi_z)
plt.axvline(0.0,color='k')
plt.axhspan(0,1,facecolor='1',alpha=1,ls='dotted')
plt.axhline(y=0.5,ls='dotted',color='k')
plt.yticks([0,0.5,1])
plt.ylim(-0.1,1.1)
plt.xlabel('z')
plt.ylabel('$\phi_z (z)$')
plt.show()

# %% [markdown]
# 使用sklearn 训练 逻辑斯蒂回归模型

# %%
from sklearn.linear_model import LogisticRegression 
lr=LogisticRegression(C=1000,random_state=0)

# %%
lr.fit(X_train_std,y_train)
# Out:
# LogisticRegression(C=1000, random_state=0)

# %%
plot_decision_regions(X_combined_std,y_combined,classifier=lr,
                     test_idx=range(105,150))
plt.xlabel('length')
plt.ylabel('width')
plt.legend(loc='upper left')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     366     if isinstance(c, str):
# ...

# %% [markdown]
# 通过正则化解决过度拟合问题
