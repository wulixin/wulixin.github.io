# %%
from functools import reduce

# %%
lst=[1,2,3,4,5]

# %%
reduce(lambda x,y:x+y,lst)
# Out:
# 15

# %%
def getStr(s):
    return ''.join(filter(str.isalpha, s))

print(*map(getStr, input().split()))

# %%
Keys = ['name', 'age']; values = ['Bill', 60]; 
d = dict(zip(Keys, values))

# %%
d['name']

# %%
d = {'name': 'Bill', 'age': 60}

# %%
np.linspace(1,2,10,endpoint=False)
