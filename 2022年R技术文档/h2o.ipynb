# %%
import h2o

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/h2o/h2o.py in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     260     try:
# --> 261         h2oconn = H2OConnection.open(url=url, ip=ip, port=port, name=name, https=https,
#     262                                      verify_ssl_certificates=verify_ssl_certificates, cacert=cacert,
#
# /opt/anaconda3/lib/python3.9/site-packages/h2o/backend/connection.py in open(server, url, ip, port, name, https, auth, verify_ssl_certificates, cacert, proxy, cookies, verbose, msgs, strict_version_check)
#     385             conn._timeout = 3.0
# --> 386             conn._cluster = conn._test_connection(retries, messages=msgs)
#     387             # If a server is unable to respond within 1s, it should be considered a bug. However we disable this
#
# /opt/anaconda3/lib/python3.9/site-packages/h2o/backend/connection.py in _test_connection(self, max_retries, messages)
#     689         else:
# --> 690             raise H2OConnectionError("Could not establish link to the H2O cloud %s after %d retries\n%s"
#     691                                      % (self._base_url, max_retries, "\n".join(errors)))
#
# H2OConnectionError: Could not establish link to the H2O cloud http://localhost:54321 after 5 retries
# [08:37.99] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe4723321c0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [08:38.21] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe448038e50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [08:38.43] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe44802ec70>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [08:38.64] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe44802e8e0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [08:38.86] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fe47246c850>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# /var/folders/xw/n8d_gn89383dctwyvrp_drr40000gn/T/ipykernel_1913/2136794291.py in <module>
#       1 from h2o.estimators.gbm import H2OGradientBoostingEstimator
# ----> 2 h2o.init()
#
# /opt/anaconda3/lib/python3.9/site-packages/h2o/h2o.py in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     276                                      ' instance of H2O with https manually '
#     277                                      '(https://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#new-user-quick-start).')
# --> 278         hs = H2OLocalServer.start(nthreads=nthreads, enable_assertions=enable_assertions, max_mem_size=mmax,
#     279                                   min_mem_size=mmin, ice_root=ice_root, log_dir=log_dir, log_level=log_level,
#     280                                   max_log_file_size=max_log_file_size, port=port, name=name,
#
# /opt/anaconda3/lib/python3.9/site-packages/h2o/backend/server.py in start(jar_path, nthreads, enable_assertions, max_mem_size, min_mem_size, ice_root, log_dir, log_level, max_log_file_size, port, name, extra_classpath, verbose, jvm_custom_args, bind_to_localhost)
#     138
#     139         if verbose: print("Attempting to start a local H2O server...")
# --> 140         hs._launch_server(port=port, baseport=baseport, nthreads=int(nthreads), ea=enable_assertions,
#     141                           mmax=max_mem_size, mmin=min_mem_size, jvm_custom_args=jvm_custom_args,
#     142                           bind_to_localhost=bind_to_localhost, log_dir=log_dir, log_level=log_level, max_log_file_size=max_log_file_size)
#
# /opt/anaconda3/lib/python3.9/site-packages/h2o/backend/server.py in _launch_server(self, port, baseport, mmax, mmin, ea, nthreads, jvm_custom_args, bind_to_localhost, log_dir, log_level, max_log_file_size)
#     271         # Find Java and check version. (Note that subprocess.check_output returns the output as a bytes object)
#     272         java = self._find_java()
# --> 273         self._check_java(java, self._verbose)
#     274
#     275         if self._verbose:
#
# /opt/anaconda3/lib/python3.9/site-packages/h2o/backend/server.py in _check_java(java, verbose)
#     376     @staticmethod
#     377     def _check_java(java, verbose):
# --> 378         jver_bytes = subprocess.check_output([java, "-version"], stderr=subprocess.STDOUT)
#     379         jver = jver_bytes.decode(encoding="utf-8", errors="ignore")
#     380         if verbose:
#
# /opt/anaconda3/lib/python3.9/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     422         kwargs['input'] = empty
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#     426
#
# /opt/anaconda3/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526         retcode = process.poll()
#     527         if check and retcode:
# --> 528             raise CalledProcessError(retcode, process.args,
#     529                                      output=stdout, stderr=stderr)
#     530     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/usr/bin/java', '-version']' returned non-zero exit status 1.

# %%
# import the cars dataset:
# this dataset is used to classify whether or not a car is economical based on
# the car's displacement, power, weight, and acceleration, and the year it was made
cars = h2o.import_file("https://s3.amazonaws.com/h2o-public-test-data/smalldata/junit/cars_20mpg.csv")

# set the predictor names and the response column name
predictors = ["displacement","power","weight","acceleration","year"]
response = "cylinders"

# split into train and validation sets
train, valid = cars.split_frame(ratios = [.8], seed = 1234)

# train a GBM model
cars_gbm = H2OGradientBoostingEstimator(distribution = "poisson", seed = 1234)
cars_gbm.train(x = predictors,
               y = response,
               training_frame = train,
               validation_frame = valid)

# retrieve the model performance
perf = cars_gbm.model_performance(valid)
perf
