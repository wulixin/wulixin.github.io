# %% [markdown]
# # 扩散模型Diffusion models in Python with esgtoolkit

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
from time import time

# %%
from esgtoolkit import simdiff, simshocks, esgplotbands
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/xw/n8d_gn89383dctwyvrp_drr40000gn/T/ipykernel_50649/2997761302.py in <module>
# ----> 1 from esgtoolkit import simdiff, simshocks, esgplotbands
#
# /opt/anaconda3/lib/python3.9/site-packages/esgtoolkit/__init__.py in <module>
#       5 __version__ = "1.0.0"
#       6
# ----> 7 from .simdiff import simdiff
#       8 from .simshocks import simshocks
#       9 from .esgcortest import esgcortest
#
# /opt/anaconda3/lib/python3.9/site-packages/esgtoolkit/simdiff.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from .config import (
#       4     R_IS_INSTALLED,
#       5     RPY2_IS_INSTALLED,
#
# /opt/anaconda3/lib/python3.9/site-packages/esgtoolkit/config.py in <module>
#       1 import pickle
# ----> 2 from rpy2.robjects import r
#       3 from subprocess import Popen, PIPE
#       4
# ...

# %%
# GBM
print(" - Geometric Brownian Motion with input shock: ----------------- \n")
start = time()
eps0 = simshocks(n = 10, horizon = 5, frequency = "quarterly", seed=13)
sim_GBM = simdiff(n = 10, horizon = 5, frequency = "quarterly",   
               model = "GBM", 
               x0 = 100, theta1 = 0.03, theta2 = 0.1, 
               eps = eps0)
print(f"Time taken: {time() - start}")
print(sim_GBM)

# %%
sim_GBM.plot(kind = 'line', legend = False)
